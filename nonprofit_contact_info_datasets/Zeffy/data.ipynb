# %%
import requests
import pandas as pd

url="https://api.zeffy.com/_new/trpc/getEmails?input=%7B%22emailDeliveryId%22%3A%22bd0c764c-640c-4097-b8f3-93e3571a992e%22%2C%22limit%22%3A100%2C%22cursor%22%3A0%7D"
headers = {
    "cookie": "_fbp=fb.1.1776298207315.209786966661945786; pscd=join.zeffy.com; _tt_enable_cookie=1; _ttp=01KP9SZD99V5H10MW4A091K69V_.tt.1; hubspotutk=67584e2a1aa2da0738ba3799c1b4a7ad; _ga=GA1.1.753230627.1776298209; AMP_MKTG_ef17265876=JTdCJTIycmVmZXJyZXIlMjIlM0ElMjJodHRwcyUzQSUyRiUyRnd3dy5nb29nbGUuY29tJTJGJTIyJTJDJTIycmVmZXJyaW5nX2RvbWFpbiUyMiUzQSUyMnd3dy5nb29nbGUuY29tJTIyJTdE; _clck=xb65wy%5E2%5Eg5m%5E0%5E2303; _rdt_uuid=1776298207503.a1ce3103-7442-496b-9fdf-76207dc57c04; _uetsid=2165fbc0433011f1bedae7c728fd86d2; _uetvid=a20df030392811f18d6b9357c29f4f8b; __hstc=251809558.67584e2a1aa2da0738ba3799c1b4a7ad.1776298210925.1777400943045.1777483388644.5; __hssrc=1; zeffy_jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiIxYzI5MDczOC1hNWMyLTQwOGQtYmEyYy04YTJhY2M2NTBkMWQiLCJvcmdhbml6YXRpb25JZCI6IjRkMWJmMGM0LWE4ZGEtNDRmOC04MDU2LWNhNjJkMzE0NTdmYiIsImlhdCI6MTc3NzQ4MzQxOCwiZXhwIjoxNzc3NTY5ODE4fQ.tveGHErS_e1fzTsCYef8ixWneNUNfpjLl5WgaSYLFPk; ttcsid_D1RCEIJC77U6050D1T5G=1777483388218::ZqCFel3VUjmkD5ZAkwfm.6.1777483418548.1; ttcsid=1777483388218::Zl3bwqkGREYuiyAp2gSh.6.1777483418549.0::1.-294.577::28385.5.638.559::0.0.0; _dcid=dcid.1.1777483418711.567023890; _gtmeec=e30%3D; _ga_173QX444NK=GS2.1.s1777483387$o6$g1$t1777483423$j24$l0$h0; _ga_00000000=GS2.1.s1777483425$o4$g0$t1777483425$j60$l0$h0; _gcl_au=1.1.1461337013.1776298207.78544500.1777483403.1777483425; session_jwt=eyJhbGciOiJSUzI1NiIsImtpZCI6Imp3ay1saXZlLWM3NjIwNjlhLTI1NGQtNGVlNi1hZjBkLTI0ODFlYTlmNmYzYyIsInR5cCI6IkpXVCJ9.....mwMPsU_1BjAQN7cSg_dQ60SqSHBQZwBDRvUS0Hevko865GdRsY4AVq9-zJgBjyvZFYBBp0G7Cd9Oz4l4WcvZWe17RXPP5GBMJscqBTtSM9-DJiPgeQa4IfivrBMGMukC55SI43_hXZS8WTWHsSJB1qdkJaQuXxNa6PWMa-eMVRw8f4-4z-ExZf6dzfm2PkMcuJRzoKVbPIMjtlKsCSUDR8UI8OQSNBpSj47NLdhIAk1XH_JCydMeBGGwzchxtgKGHLTVHlxQtnxOHnjAkpmeu9bds_dP98e3GNYTDuAOO2ceSW4CVjv1vPJXbk62Ia_G4SM1ZhgO4651yoieMSEozg; AMP_ef17265876=...; _clsk=urzwkv%5E1777485008746%5E21%5E1%5Ee.clarity.ms%2Fcollect",
    "accept": "application/json"
}

r = requests.get(url, headers=headers)


data = r.json()

items = data["result"]["data"]["items"]

df = pd.DataFrame(items)

df.to_csv("zeffy_results.csv", index=False)

df
# Out:
#                                      id                             contactId  \
# 0  43a3bbb6-c0bf-4766-976e-e019c9b0cd86  72be9793-7ee5-49c9-9dc9-0acdf255611c
#
#                contactEmail        status contactFirstName contactLastName
# 0  sri.talari@cc-energy.org  Unsubscribed              Sri          Talari
