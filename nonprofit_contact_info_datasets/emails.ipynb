# %%
import pandas as pd

# %%
df= pd.read_csv('nonprofit_contact_info_verified.csv')
df
# Out:
#      Unnamed: 0                        source_file          ein  \
# 0             0  XML/202520639349300932_public.xml  920731572.0
# 1             1  XML/202511769349301316_public.xml  455009704.0
# 2             2                                NaN          NaN
# 3             3  XML/202501689349301205_public.xml  464603670.0
# 4             4                                NaN          NaN
# ..          ...                                ...          ...
# 796         796                                NaN          NaN
# 797         797  XML/202510499349302046_public.xml  951399555.0
# 798         798  XML/202500459349301655_public.xml  815467728.0
# 799         799                                NaN          NaN
# 800         800                                NaN          NaN
#
#                                 org_name               org_type  \
# 0                     1904 Baseball Club    San Diego Nonprofit
# 1                               2020 Mom  California Nonprofit
# ...

# %%
df['all_emails'][2].split(', ')
# Out:
# ['211help@211sandiego.org',
#  'media@211sandiego.org',
#  'resourcecenter@211sandiego.org',
#  '211connections@211sandiego.org']

# %%
import smtplib
from email.mime.text import MIMEText

def email_generation(row):
    sender_email = "youremail@gmail.com"
    password = "rggmfhphhfcslgnn"  
    subject = "Subject here"
    server = smtplib.SMTP("smtp.gmail.com", 587)
    server.starttls()
    server.login(sender_email, password)
    # row['all_emails'].split()
    for receiver in row['all_emails'].split(', '):
        body = f"Dear, name \n We are reaching out to you today because you are a key member of {row['org_name']}. Blah Blah Blah"
        msg = MIMEText(body)
        msg['Subject'] = subject
        msg['From'] = sender_email
        msg['To'] = receiver

        server.sendmail(sender_email, receiver, msg.as_string())

    server.quit()

# %%
import smtplib
from email.mime.text import MIMEText

sender_email = "supratiksri7@gmail.com"
password = "rggmfhphhfcslgnn"  # your app password (no spaces)

subject = "Test Email"
body = "This is a test email to myself."

server = smtplib.SMTP("smtp.gmail.com", 587)
server.starttls()
server.login(sender_email, password)

receiver = "supratiksri7@gmail.com"

msg = MIMEText(body)
msg['Subject'] = subject
msg['From'] = sender_email
msg['To'] = receiver

server.sendmail(sender_email, receiver, msg.as_string())

server.quit()
# Out:
# (221,
#  b'2.0.0 closing connection 5a478bee46e88-2de8c10a688sm5470004eec.4 - gsmtp')
